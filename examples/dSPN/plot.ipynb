# %%
from dspn_analysis import dSPNanalysis
optR = dSPNanalysis('dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20210212/dopamine/ID_0')
optR.load()
parameterID = optR.modulation_setup['parameterID']
# Out:
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodcell/analysis.py:37: UserWarning: loadtxt: Empty input file: "dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20210212/dopamine/ID_0/voltage_modulation_pass.csv"
#   self.voltage_modulation_pass = np.loadtxt(self.dir_path /  'voltage_modulation_pass.csv')

# %%
optR.plot_control(title='D1 modulation dSPN',save=True,filename='control_' + str(parameterID)+'.svg')
# Out:
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodcell/analysis.py:62: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodcell/analysis.py:62: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_all_traces(title='D1 modulation dSPN',save=True,filename='example_' + str(parameterID)+'.svg')
# Out:
# No handles with labels found to put in legend.
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodcell/analysis.py:94: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodcell/analysis.py:94: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_validated_traces_with_control(titles='D1 modulation dSPN',save=True,filename='validated_' + str(parameterID)+'.svg')
# Out:
#  No passing models
# /home/jofrony/Documents/Repositories/Neuromodcell/examples/dSPN/dspn_analysis.py:228: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/Documents/Repositories/Neuromodcell/examples/dSPN/dspn_analysis.py:228: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
from dspn_analysis import dSPNanalysis
optR = dSPNanalysis('dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20210212/dopamine/ID_1')
optR.load()
parameterID = optR.modulation_setup['parameterID']

# %%
optR.plot_control(title='D1 modulation dSPN',save=True,filename='control_' + str(parameterID)+'.pdf')

# %%
optR.plot_all_traces(title='D1 modulation dSPN',save=True,filename='example_' + str(parameterID)+'.pdf')

# %%
optR.plot_validated_traces_with_control(titles='D1 modulation dSPN',save=True,filename='validated_' + str(parameterID)+'.pdf')

# %%
from dspn_analysis import dSPNanalysis
optR = dSPNanalysis('dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20210212/dopamine/ID_2')
optR.load()
parameterID = optR.modulation_setup['parameterID']

# %%
optR.plot_control(title='D1 modulation dSPN',save=True,filename='control_' + str(parameterID)+'.pdf')

# %%
optR.plot_all_traces(title='D1 modulation dSPN',save=True,filename='example_' + str(parameterID)+'.pdf')

# %%
optR.plot_validated_traces_with_control(titles='D1 modulation dSPN',save=True,filename='validated_' + str(parameterID)+'.pdf')

# %%
from dspn_analysis import dSPNanalysis
optR = dSPNanalysis('dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20210212/dopamine/ID_3')
optR.load()
parameterID = optR.modulation_setup['parameterID']

# %%
optR.plot_control(title='D1 modulation dSPN',save=True,filename='control_' + str(parameterID)+'.pdf')

# %%
optR.plot_all_traces(title='D1 modulation dSPN',save=True,filename='example_' + str(parameterID)+'.pdf')

# %%
optR.plot_validated_traces_with_control(titles='D1 modulation dSPN',save=True,filename='validated_' + str(parameterID)+'.pdf')
