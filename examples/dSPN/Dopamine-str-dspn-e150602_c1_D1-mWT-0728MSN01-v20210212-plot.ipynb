# %%
from neuromodulation.analysis import optimisationResult
optR = optimisationResult('dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20210212/dopamine/')
optR.load()
parameterID = optR.modulation_setup['parameterID']

# %%
optR.plot_control(title='D1 modulation dSPN',
                  save=True,
                  filename='control_ID_' + str(parameterID)+'.pdf')
# Out:
# /home/miseno/.local/lib/python3.6/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/miseno/.local/lib/python3.6/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_all_traces(title='D1 modulation dSPN',
                     save=True,
                     filename='opt_neuromodulated_models_ID_' + str(parameterID)+'.pdf')
# Out:
# No handles with labels found to put in legend.
# /home/miseno/.local/lib/python3.6/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/miseno/.local/lib/python3.6/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
